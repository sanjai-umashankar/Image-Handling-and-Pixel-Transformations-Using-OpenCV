# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg', cv2.IMREAD_COLOR)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb, cmap='viridis') 
plt.title("Original Image")
plt.axis('off')  
plt.show()

# %%
Draw a line from the top-left to the bottom-right of the image

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (600, 768, 3)

# %%
line_img = cv2.line(img_rgb, (0, 0), (768, 600), (255, 0, 0), 2)

# %%
plt.imshow(line_img, cmap='viridis')  
plt.title("Image with Line")
plt.axis('off')  
plt.show()

# %%
Draw a circle at the center of the image .

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (600, 768, 3)

# %%
circle_img = cv2.circle(img_rgb,(400,300),150,(255,0,0),10)

# %%
plt.imshow(circle_img, cmap='viridis')  
plt.title("Image with Circle")
plt.axis('off')  
plt.show()

# %%
Draw a rectangle around  the whole image .

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (600, 768, 3)

# %%
rectangle_img = cv2.rectangle(img_rgb, (0, 0), (768, 600), (0, 0, 255), 10)

# %%
plt.imshow(rectangle_img, cmap='viridis')  
plt.title("Image with Rectangle")
plt.axis('off')  
plt.show()

# %%
Add the text "OpenCV Drawing" at the top-left corner of the image.

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
text_img = cv2.putText(img_rgb, "OpenCV Drawing", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 10)

# %%
plt.imshow(text_img, cmap='viridis')  
plt.title("Image with Text")
plt.axis('off')  
plt.show()

# %%
Convert the image from RGB to HSV and display it.

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Original RGB Image
plt.imshow(image_rgb)
plt.title("Original RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
Convert RGB to HSV

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# %%
plt.imshow(image_hsv)
plt.title("HSV Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
Convert RGB to GRAY

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(image_gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
Convert RGB to YCrCb

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image_ycrcb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# %%
plt.imshow(image_ycrcb)
plt.title("YCrCb Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
Convert HSV back to RGB

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image_hsv_to_rgb = cv2.cvtColor(image_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(image_hsv_to_rgb)
plt.title("HSV to RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
o Access and print the value of the pixel at coordinates (100, 100). 

o Modify the color of the pixel at (200, 200) to white.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image[200:500, 200:500] = [255, 255, 255]

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.title("Image with 300x300 White Block")
plt.axis("off")
plt.show()

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image.shape
# Out:
# (600, 768, 3)

# %%
resized_image = cv2.resize(image, (768 // 2, 600 // 2))

# %%
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

# %%
resized_image_rgb.shape
# Out:
# (300, 384, 3)

# %%
plt.imshow(resized_image_rgb)
plt.title("Resized Image (Half Size)")
plt.axis("off")
plt.show()

# %%
Step6:
o Crop a region of interest (ROI) from the image (e.g., a 100x100 pixel area starting at (50, 50)) and display it.

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
image.shape
# Out:
# (600, 768, 3)

# %%
roi = image[50:350, 50:350]

# %%
roi_rgb = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(roi_rgb)
plt.title("Cropped Region of Interest (ROI)")
plt.axis("off")
plt.show()

# %%
Step7:
o Flip the original image horizontally and display it. 

o Flip the original image vertically and display it.

# %%
image = cv2.imread(r'C:\Users\admin\Downloads\Digital-mage-Processing-using-OpenCV--main (2)\Digital-mage-Processing-using-OpenCV--main\Digital-mage-Processing-using-OpenCV--main\Qno. 1.jpg')

# %%
flipped_horizontally = cv2.flip(image, 1)

# %%
flipped_horizontally_rgb = cv2.cvtColor(flipped_horizontally, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flipped_horizontally_rgb)
plt.title("Flipped Horizontally")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))

# %%
flipped_vertically = cv2.flip(image, 0)

# %%
flipped_vertically_rgb = cv2.cvtColor(flipped_vertically, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flipped_vertically_rgb)
plt.title("Flipped Vertically")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(599.5), np.float64(-0.5))
